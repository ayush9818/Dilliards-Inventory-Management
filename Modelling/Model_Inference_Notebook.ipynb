# %%
import pandas as pd
import os
import json
import numpy as np
import joblib
import warnings

warnings.filterwarnings('ignore')

# %%
data_dir = os.path.join(os.path.dirname(os.getcwd()),'data')
model_dir = os.path.join(os.path.dirname(os.getcwd()),'models')
file_name = 'df_final_sku_store_quarter_v2.csv'
top_k_brands_file = 'top_k_brands.json'
model_name = 'xgboost.joblib'

data_path = os.path.join(data_dir, file_name)
assert os.path.exists(data_path), f"{file_name} does not exist"

# %% [markdown]
# ## Model Loading
#
# - **Final Model Used**
#     - Xgboost Regressor
# - **Hyper parameters**
#     - 'colsample_bytree': 1.0
#     - 'learning_rate': 0.3
#     - 'max_depth': 9
#     - 'n_estimators': 200
#     - 'subsample': 1.0

# %%
# Loading the final Model 
model = joblib.load(os.path.join(model_dir, model_name))

# %% [markdown]
# ## Data Loading
#
# - Load entire feature engineered dataframe into the memory
# - Created two copies, one to use for prediction and one for ROI analysis
# - Transformed Categorical Variables to one hot and Cost related variables on log scale
# - Dropped the unnecessary columns

# %%
df_orig = pd.read_csv(data_path)
df_orig.head()
# Out:
#    STORE  COUNT_ITEMS  MenRatio      White     Asian        Income    Poverty  \
# 0    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 1    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 2    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 3    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 4    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
#
#    Professional  Construction  Unemployment  ...   VENDOR     BRAND CLASSID  \
# 0     31.208955     12.074627      7.765672  ...  5016699  TIMBERLA     913
# 1     31.208955     12.074627      7.765672  ...  6713105  INTERNAT     203
# 2     31.208955     12.074627      7.765672  ...  9520439  BALI/HEN     873
# 3     31.208955     12.074627      7.765672  ...  5010255  ENZO ANG     214
# 4     31.208955     12.074627      7.765672  ...  5010255  ENZO ANG     214
#
#     CITY  STATE    ZIP  COST  RETAIL  PROF_MARG  DISCOUNTED
# 0  TAMPA     FL  33607  38.0    79.0   0.481013        True
# 1  TAMPA     FL  33607   2.0     3.0   0.666667        True
# 2  TAMPA     FL  33607   8.0    18.0   0.444444       False
# 3  TAMPA     FL  33607  28.5    60.0   0.475000        True
# 4  TAMPA     FL  33607  28.5    60.0   0.475000        True
#
# [5 rows x 30 columns]

# %%
# Creating Dataframe for ROI Analysis
df_save = df_orig.copy()
df_save = df_save.reset_index()
df_save['revenue'] = df_save['averagesellingprice'] * df_save['totalunitssold']
original_keep_cols = ['index','STORE','SKU', 'year', 'quarter', 'revenue']
df_save = df_save[original_keep_cols]
df_save.head()
# Out:
#    index  STORE   SKU  year quarter  revenue
# 0      0    102   387  2004      Q4   131.93
# 1      1    102   450  2005      Q3    10.08
# 2      2    102   788  2004      Q3    36.00
# 3      3    102  1634  2004      Q3    66.00
# 4      4    102  1634  2004      Q4   168.00

# %%
df_save['pred_log_revenue'] = 0

# %%
df = df_orig.copy()

# %%
df.head()
# Out:
#    STORE  COUNT_ITEMS  MenRatio      White     Asian        Income    Poverty  \
# 0    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 1    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 2    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 3    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 4    102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
#
#    Professional  Construction  Unemployment  ...   VENDOR     BRAND CLASSID  \
# 0     31.208955     12.074627      7.765672  ...  5016699  TIMBERLA     913
# 1     31.208955     12.074627      7.765672  ...  6713105  INTERNAT     203
# 2     31.208955     12.074627      7.765672  ...  9520439  BALI/HEN     873
# 3     31.208955     12.074627      7.765672  ...  5010255  ENZO ANG     214
# 4     31.208955     12.074627      7.765672  ...  5010255  ENZO ANG     214
#
#     CITY  STATE    ZIP  COST  RETAIL  PROF_MARG  DISCOUNTED
# 0  TAMPA     FL  33607  38.0    79.0   0.481013        True
# 1  TAMPA     FL  33607   2.0     3.0   0.666667        True
# 2  TAMPA     FL  33607   8.0    18.0   0.444444       False
# 3  TAMPA     FL  33607  28.5    60.0   0.475000        True
# 4  TAMPA     FL  33607  28.5    60.0   0.475000        True
#
# [5 rows x 30 columns]

# %%
# Creating Dataframe for Prediction
df['STORE']=df['STORE'].astype('str')
df['DEPT']=df['DEPT'].astype('str')
df['VENDOR']=df['VENDOR'].astype('str')
for col in df.columns:
    if df[col].dtype == 'O':
        print(col, df[col].unique().shape[0])
# Out:
# STORE 325
# quarter 4
# DEPT 60
# VENDOR 1360
# BRAND 1133
# CLASSID 756
# CITY 264
# STATE 29

# %%
# Loading top 20 brands used in model training for prediction
top_k_brands = json.load(open(os.path.join(model_dir, top_k_brands_file)))
print(top_k_brands)
# Out:
# ['CLINIQUE', 'CABERNET', 'POLO FAS', 'ROUNDTRE', 'LIZ CLAI', 'LANCOME', 'EMMA JAM', 'BROWN SH', 'CALVIN K', 'TOMMY HI', 'BYER CAL', 'NOBLE EX', 'LEVI STR', 'CHANEL I', 'KIDS HEA', 'DAX CORP', 'KORET OF', 'VANITY F', 'NOBILITY', 'WESTPOIN']

# %%
# Converting Revenue on Log Scale
df['revenue'] = df['averagesellingprice'] * df['totalunitssold']
df['log_revenue'] = np.log(df['revenue']+1)
df.drop(columns = ['averagesellingprice', 'totalunitssold'],axis=1, inplace=True)

# %%
df.head()
# Out:
#   STORE  COUNT_ITEMS  MenRatio      White     Asian        Income    Poverty  \
# 0   102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 1   102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 2   102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 3   102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 4   102        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
#
#    Professional  Construction  Unemployment  ...  CLASSID   CITY STATE    ZIP  \
# 0     31.208955     12.074627      7.765672  ...      913  TAMPA    FL  33607
# 1     31.208955     12.074627      7.765672  ...      203  TAMPA    FL  33607
# 2     31.208955     12.074627      7.765672  ...      873  TAMPA    FL  33607
# 3     31.208955     12.074627      7.765672  ...      214  TAMPA    FL  33607
# 4     31.208955     12.074627      7.765672  ...      214  TAMPA    FL  33607
#
#    COST  RETAIL PROF_MARG  DISCOUNTED revenue log_revenue
# 0  38.0    79.0  0.481013        True  131.93    4.889823
# 1   2.0     3.0  0.666667        True   10.08    2.405142
# 2   8.0    18.0  0.444444       False   36.00    3.610918
# 3  28.5    60.0  0.475000        True   66.00    4.204693
# 4  28.5    60.0  0.475000        True  168.00    5.129899
#
# [5 rows x 30 columns]

# %%
# One Hot Encoding for Brand Names and Dropping the unnecessary columns not used for prediction
for brand in top_k_brands:
    df[brand] = np.where(df['BRAND']==brand,1,0) 
    
drop_cols = [
    'SKU', 'year','purchase_count', 'return_count', 'VENDOR', 'CITY', 'BRAND', 'PROF_MARG', 'ZIP'
]

df.drop(columns=drop_cols , axis=1, inplace=True)

# %%
# Converting Cost, retail and original price on log scale
df['COST'] = np.log(df['COST']+1)
df['RETAIL'] = np.log(df['RETAIL']+1)
df['averageoriginalprice'] = np.log(df['averageoriginalprice']+1)

# %%
# Encoding one hot for categorical variables
cat_variables = ['STORE', 'quarter', 'DEPT', 'CLASSID', 'STATE']
df_final = pd.get_dummies(df, columns=cat_variables, drop_first=True)
df_final.head()
# Out:
#    COUNT_ITEMS  MenRatio      White     Asian        Income    Poverty  \
# 0        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 1        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 2        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 3        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 4        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
#
#    Professional  Construction  Unemployment  averageoriginalprice  ...  \
# 0     31.208955     12.074627      7.765672              4.382027  ...
# 1     31.208955     12.074627      7.765672              1.945910  ...
# 2     31.208955     12.074627      7.765672              2.944439  ...
# 3     31.208955     12.074627      7.765672              4.110874  ...
# 4     31.208955     12.074627      7.765672              4.110874  ...
#
#    STATE_NM  STATE_NV  STATE_OH  STATE_OK  STATE_SC  STATE_TN  STATE_TX  \
# 0     False     False     False     False     False     False     False
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
#
#    STATE_UT  STATE_VA  STATE_WY
# 0     False     False     False
# 1     False     False     False
# 2     False     False     False
# 3     False     False     False
# 4     False     False     False
#
# [5 rows x 1205 columns]

# %%
df_final.columns
# Out:
# Index(['COUNT_ITEMS', 'MenRatio', 'White', 'Asian', 'Income', 'Poverty',
#        'Professional', 'Construction', 'Unemployment', 'averageoriginalprice',
#        ...
#        'STATE_NM', 'STATE_NV', 'STATE_OH', 'STATE_OK', 'STATE_SC', 'STATE_TN',
#        'STATE_TX', 'STATE_UT', 'STATE_VA', 'STATE_WY'],
#       dtype='object', length=1205)

# %%
train_columns = json.load(open(os.path.join(model_dir,'columns.json')))

for col in train_columns:
    if col not in df_final.columns:
        print(col)
# Out:
# CLASSID_717
# CLASSID_864

# %%
df_final['CLASSID_717'] = False
df_final['CLASSID_864'] = False

# %%
df_final.drop(columns=['log_revenue','revenue'], axis=1, inplace=True)

# %%
df_final.head()
# Out:
#    COUNT_ITEMS  MenRatio      White     Asian        Income    Poverty  \
# 0        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 1        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 2        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 3        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
# 4        96312  0.514077  68.120896  1.543284  47144.328358  17.150746
#
#    Professional  Construction  Unemployment  averageoriginalprice  ...  \
# 0     31.208955     12.074627      7.765672              4.382027  ...
# 1     31.208955     12.074627      7.765672              1.945910  ...
# 2     31.208955     12.074627      7.765672              2.944439  ...
# 3     31.208955     12.074627      7.765672              4.110874  ...
# 4     31.208955     12.074627      7.765672              4.110874  ...
#
#    STATE_OH  STATE_OK  STATE_SC  STATE_TN  STATE_TX  STATE_UT  STATE_VA  \
# 0     False     False     False     False     False     False     False
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
#
#    STATE_WY  CLASSID_717  CLASSID_864
# 0     False        False        False
# 1     False        False        False
# 2     False        False        False
# 3     False        False        False
# 4     False        False        False
#
# [5 rows x 1205 columns]

# %%
del df_orig

# %%
del df

# %%
train_columns.remove('revenue')
df_final = df_final[train_columns]

# %% [markdown]
# ## Model Prediction

# %%
# Batch Prediction for Xgboost, since the system will run out of memory for 6million row data
batch_size = 50000
total_size = df_final.shape[0]

for start_idx in range(0,total_size,batch_size):
    print(f"Start Index : {start_idx}")
    X_test = df_final.iloc[start_idx:start_idx+batch_size,]
    y_pred = model.predict(X_test)
    
    test_indices = list(X_test.index)
    df_save.loc[test_indices,'pred_log_revenue'] = list(y_pred)
    
    df_save.to_csv(os.path.join(model_dir, 'df_roi_pred.csv'), index=False)
# Out:
# Start Index : 0
# Start Index : 50000
# Start Index : 100000
# Start Index : 150000
# Start Index : 200000
# Start Index : 250000
# Start Index : 300000
# Start Index : 350000
# Start Index : 400000
# Start Index : 450000
# Start Index : 500000
# Start Index : 550000
# Start Index : 600000
# Start Index : 650000
# Start Index : 700000
# Start Index : 750000
# Start Index : 800000
# Start Index : 850000
# Start Index : 900000
# Start Index : 950000
# Start Index : 1000000
# Start Index : 1050000
# Start Index : 1100000
# Start Index : 1150000
# Start Index : 1200000
# Start Index : 1250000
# Start Index : 1300000
# Start Index : 1350000
# Start Index : 1400000
# Start Index : 1450000
# Start Index : 1500000
# Start Index : 1550000
# Start Index : 1600000
# Start Index : 1650000
# Start Index : 1700000
# Start Index : 1750000
# Start Index : 1800000
# Start Index : 1850000
# Start Index : 1900000
# Start Index : 1950000
# Start Index : 2000000
# Start Index : 2050000
# Start Index : 2100000
# Start Index : 2150000
# Start Index : 2200000
# Start Index : 2250000
# Start Index : 2300000
# Start Index : 2350000
# Start Index : 2400000
# Start Index : 2450000
# Start Index : 2500000
# Start Index : 2550000
# Start Index : 2600000
# Start Index : 2650000
# Start Index : 2700000
# Start Index : 2750000
# Start Index : 2800000
# Start Index : 2850000
# Start Index : 2900000
# Start Index : 2950000
# Start Index : 3000000
# Start Index : 3050000
# Start Index : 3100000
# Start Index : 3150000
# Start Index : 3200000
# Start Index : 3250000
# Start Index : 3300000
# Start Index : 3350000
# Start Index : 3400000
# Start Index : 3450000
# Start Index : 3500000
# Start Index : 3550000
# Start Index : 3600000
# Start Index : 3650000
# Start Index : 3700000
# Start Index : 3750000
# Start Index : 3800000
# Start Index : 3850000
# Start Index : 3900000
# Start Index : 3950000
# Start Index : 4000000
# Start Index : 4050000
# Start Index : 4100000
# Start Index : 4150000
# Start Index : 4200000
# Start Index : 4250000
# Start Index : 4300000
# Start Index : 4350000
# Start Index : 4400000
# Start Index : 4450000
# Start Index : 4500000
# Start Index : 4550000
# Start Index : 4600000
# Start Index : 4650000
# Start Index : 4700000
# Start Index : 4750000
# Start Index : 4800000
# Start Index : 4850000
# Start Index : 4900000
# Start Index : 4950000
# Start Index : 5000000
# Start Index : 5050000
# Start Index : 5100000
# Start Index : 5150000
# Start Index : 5200000
# Start Index : 5250000
# Start Index : 5300000
# Start Index : 5350000
# Start Index : 5400000
# Start Index : 5450000
# Start Index : 5500000
# Start Index : 5550000
# Start Index : 5600000
# Start Index : 5650000
# Start Index : 5700000
# Start Index : 5750000
# Start Index : 5800000
# Start Index : 5850000
# Start Index : 5900000
# Start Index : 5950000
# Start Index : 6000000
# Start Index : 6050000
# Start Index : 6100000

# %%
df_save.to_csv(os.path.join(model_dir, 'df_roi_pred.csv'), index=False)

# %%
df_save.shape
# Out:
# (6105994, 7)

# %%
df_save['pred_revenue'] = np.exp(df_save['pred_log_revenue']) - 1
df_save.head()
# Out:
#    index  STORE   SKU  year quarter  revenue  pred_log_revenue  pred_revenue
# 0      0    102   387  2004      Q4   131.93          5.303100    199.958840
# 1      1    102   450  2005      Q3    10.08          2.225951      8.262289
# 2      2    102   788  2004      Q3    36.00          3.946944     50.776907
# 3      3    102  1634  2004      Q3    66.00          4.895599    132.700118
# 4      4    102  1634  2004      Q4   168.00          5.033957    152.539441

# %% [markdown]
# ## Baseline Calculation
#
# - Logic Used
#     - Baseline average selling price of a SKU at a particular store will be the selling price of that SKU in the previous quarter

# %%
def previous_quarter(quarter, year):
    q_num = int(quarter[-1])  # Extract the quarter number (assuming format 'Q1', 'Q2', etc.)
    if q_num == 1:
        return 'Q4', year - 1
    else:
        return f'Q{q_num - 1}', year

# %%
df_save[['prev_quarter', 'prev_year']] = df_save.apply(lambda x: previous_quarter(x['quarter'], x['year']), axis=1, result_type='expand')

prev_revenue_df = df_save[['STORE', 'SKU', 'quarter', 'year', 'revenue']].copy()
prev_revenue_df = prev_revenue_df.rename(columns={'quarter': 'prev_quarter', 'year': 'prev_year', 'revenue': 'prev_revenue'})
df_save = df_save.merge(prev_revenue_df, how='left', on=['STORE', 'SKU', 'prev_quarter', 'prev_year'])

df_save.drop(['prev_quarter', 'prev_year'], axis=1, inplace=True)
df_save.loc[(df_save['quarter'] == 'Q1') & (df_save['year'] == 2004), 'prev_revenue'] = pd.NA
df_save.rename(columns={'prev_revenue': 'base_line'}, inplace=True)

# %%
df_save.head()
# Out:
#    index  STORE   SKU  year quarter  revenue  pred_log_revenue  pred_revenue  \
# 0      0    102   387  2004      Q4   131.93          5.303100    199.958840
# 1      1    102   450  2005      Q3    10.08          2.225951      8.262289
# 2      2    102   788  2004      Q3    36.00          3.946944     50.776907
# 3      3    102  1634  2004      Q3    66.00          4.895599    132.700118
# 4      4    102  1634  2004      Q4   168.00          5.033957    152.539441
#
#    base_line
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4       66.0

# %%
df_save[~df_save.base_line.isnull()]
# Out:
#            index  STORE      SKU  year quarter  revenue  pred_log_revenue  \
# 4              4    102     1634  2004      Q4   168.00          5.033957
# 25            25    102     7915  2004      Q4    97.50          5.462652
# 26            26    102     7915  2005      Q1   156.00          5.034359
# 27            27    102     7915  2005      Q2   156.00          5.239471
# 31            31    102     8224  2005      Q3    32.00          3.787999
# ...          ...    ...      ...   ...     ...      ...               ...
# 6105960  6105960   9909  5168252  2005      Q3    20.00          3.301930
# 6105962  6105962   9909  5168362  2005      Q3    22.91          3.308795
# 6105966  6105966   9909  5170159  2005      Q3    58.00          4.329112
# 6105969  6105969   9909  5170885  2005      Q1   198.00          4.271519
# 6105992  6105992   9909  5179773  2005      Q3    19.00          3.434469
#
#          pred_revenue  base_line
# 4          152.539441      66.00
# 25         234.721779      39.00
# 26         152.601099      97.50
# 27         187.570404     156.00
# 31          43.167928      32.00
# ...               ...        ...
# 6105960     26.165028      20.00
# 6105962     26.352146      11.69
# 6105966     74.876882      58.00
# 6105969     70.630373     176.00
# 6105992     30.014931      57.99
#
# [1417665 rows x 9 columns]

# %%
df_save[(df_save.STORE == 9909) & (df_save.SKU == 5179773)]
# Out:
#            index  STORE      SKU  year quarter  revenue  pred_log_revenue  \
# 6105991  6105991   9909  5179773  2005      Q2    57.99          3.731722
# 6105992  6105992   9909  5179773  2005      Q3    19.00          3.434469
#
#          pred_revenue  base_line
# 6105991     40.750926        NaN
# 6105992     30.014931      57.99

# %%
df_save.to_csv(os.path.join(model_dir,'final_roi_analysis.csv'), index=False)

# %%
import pandas as pd

data_dir = os.path.join(os.path.dirname(os.getcwd()),'data')
model_dir = os.path.join(os.path.dirname(os.getcwd()),'models')
file_name = 'df_final_sku_store_quarter_v2.csv'

df = pd.read_csv(os.path.join(data_dir, file_name))
df_roi = pd.read_csv(os.path.join(model_dir, 'final_roi_analysis.csv'))

# %%
df.columns
# Out:
# Index(['STORE', 'COUNT_ITEMS', 'MenRatio', 'White', 'Asian', 'Income',
#        'Poverty', 'Professional', 'Construction', 'Unemployment', 'SKU',
#        'year', 'quarter', 'totalunitssold', 'averageoriginalprice',
#        'averagesellingprice', 'purchase_count', 'return_count', 'DEPT',
#        'PACKSIZE', 'VENDOR', 'BRAND', 'CLASSID', 'CITY', 'STATE', 'ZIP',
#        'COST', 'RETAIL', 'PROF_MARG', 'DISCOUNTED'],
#       dtype='object')

# %%
df = df[['STORE','SKU','totalunitssold', 'quarter', 'year', 'averageoriginalprice','averagesellingprice']]

# %%
df_final = pd.merge(df_roi, df, on=['STORE','SKU','quarter','year'], how='inner')
df_final.shape, df_roi.shape
# Out:
# ((6105994, 12), (6105994, 9))

# %%
df_final.to_csv(os.path.join(model_dir, 'final_roi_analysis_v2.csv'), index=False)
